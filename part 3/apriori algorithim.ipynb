# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pip install apriori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("TV Shows - Association Rule Learning.csv")

# %%
df
# Out:
#           Cobra Kai          Lupin          12 Monkeys          Sherlock  \
# 0              Lost      Jack Ryan           The Flash   Game of thrones
# 1     Sex Education      Dr. House             Kingdom  The Walking Dead
# 2             Ozark  Sex Education         Constantine          Preacher
# 3            Naruto            NaN                 NaN               NaN
# 4     Sex Education            NaN                 NaN               NaN
# ...             ...            ...                 ...               ...
# 9684      One Piece  The Blacklist  Two and a half men             Lupin
# 9685      One Piece      Mr. Robot          Succession             Ozark
# 9686      Daredevil       Atypical               Heros               NaN
# 9687       Absentia   The Newsroom        The Alienist               NaN
# 9688       Atypical            NaN                 NaN               NaN
#
#           Unnamed: 4             Unnamed: 5           Unnamed: 6 Unnamed: 7  \
# ...

# %%
df.isnull().sum()
# Out:
# Cobra Kai         0
# Lupin          2133
# 12 Monkeys     3743
# Sherlock       5023
# Unnamed: 4     6011
# Unnamed: 5     6852
# Unnamed: 6     7492
# Unnamed: 7     8025
# Unnamed: 8     8458
# Unnamed: 9     8802
# Unnamed: 10    9045
# Unnamed: 11    9225
# Unnamed: 12    9341
# Unnamed: 13    9417
# Unnamed: 14    9493
# Unnamed: 15    9548
# Unnamed: 16    9594
# Unnamed: 17    9623
# Unnamed: 18    9637
# Unnamed: 19    9651
# Unnamed: 20    9660
# Unnamed: 21    9671
# Unnamed: 22    9675
# Unnamed: 23    9681
# Unnamed: 24    9682
# Unnamed: 25    9682
# Unnamed: 26    9683
# Unnamed: 27    9684
# Unnamed: 28    9685
# Unnamed: 29    9688
# Unnamed: 30    9688
# Unnamed: 31    9688
# dtype: int64

# %%
df.shape
# Out:
# (9689, 32)

# %%
threshold = 9500
df = df.dropna(axis=1, thresh=len(df) - threshold + 1)

# %%
df = df.fillna("Unknown")

# %%
df
# Out:
#           Cobra Kai          Lupin          12 Monkeys          Sherlock  \
# 0              Lost      Jack Ryan           The Flash   Game of thrones
# 1     Sex Education      Dr. House             Kingdom  The Walking Dead
# 2             Ozark  Sex Education         Constantine          Preacher
# 3            Naruto        Unknown             Unknown           Unknown
# 4     Sex Education        Unknown             Unknown           Unknown
# ...             ...            ...                 ...               ...
# 9684      One Piece  The Blacklist  Two and a half men             Lupin
# 9685      One Piece      Mr. Robot          Succession             Ozark
# 9686      Daredevil       Atypical               Heros           Unknown
# 9687       Absentia   The Newsroom        The Alienist           Unknown
# 9688       Atypical        Unknown             Unknown           Unknown
#
#           Unnamed: 4             Unnamed: 5           Unnamed: 6 Unnamed: 7  \
# ...

# %%
df.describe()
# Out:
#         Cobra Kai    Lupin 12 Monkeys Sherlock Unnamed: 4 Unnamed: 5  \
# count        9689     9689       9689     9689       9689       9689
# unique        156      146        148      146        143        131
# top     Daredevil  Unknown    Unknown  Unknown    Unknown    Unknown
# freq          811     2133       3743     5023       6011       6852
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# count        9689       9689       9689       9689        9689        9689
# unique        133        134        123        116         112         101
# top       Unknown    Unknown    Unknown    Unknown     Unknown     Unknown
# freq         7492       8025       8458       8802        9045        9225
#
#        Unnamed: 12 Unnamed: 13 Unnamed: 14
# count         9689        9689        9689
# unique          86          83          72
# top        Unknown     Unknown     Unknown
# freq          9341        9417        9493

# %%
df.shape
# Out:
# (9689, 15)

# %%
records = []
for i in range(0, 9689):
    records.append([str(df.values[i, j]) for j in range(0, 15)])

# %%
from apyori import apriori

association_rules = apriori(

    records, min_support=0.0045, min_confidence=0.6, min_lift=3, min_length=2)

association_results = list(association_rules)

# %%
association_results
# Out:
# [RelationRecord(items=frozenset({'Ozark', 'Demon Slayer', 'Family Guy'}), support=0.005573330581071318, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Demon Slayer', 'Family Guy'}), items_add=frozenset({'Ozark'}), confidence=0.6000000000000001, lift=3.0971763452317536)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Ozark', 'Succession'}), support=0.005779750232222107, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Succession'}), items_add=frozenset({'Ozark'}), confidence=0.6021505376344085, lift=3.108277335716454)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Ozark', 'The Blacklist', 'Atypical'}), support=0.005057281453194344, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist', 'Atypical'}), items_add=frozenset({'Ozark'}), confidence=0.6125, lift=3.1617008524240813)]),
# ...

# %%
print(len(association_results))
# Out:
# 6

# %%
# print the rules, the support, the confidence, and lift for each rule
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Ozark -> Demon Slayer
# Support: 0.005573330581071318
# Confidence: 0.6000000000000001
# Lift: 3.0971763452317536
# ...
# Rule: Mr. Robot -> Ozark
# Support: 0.005779750232222107
# Confidence: 0.6021505376344085
# Lift: 3.108277335716454
# ...
# Rule: Mr. Robot -> Ozark
# Support: 0.005057281453194344
# Confidence: 0.6125
# Lift: 3.1617008524240813
# ...
# Rule: Mr. Robot -> Ozark
# Support: 0.005779750232222107
# Confidence: 0.6292134831460674
# Lift: 3.2479751935014636
# ...
# Rule: Mr. Robot -> Ozark
# Support: 0.00454123232531737
# Confidence: 0.7857142857142858
# Lift: 4.055826166374915
# ...
# Rule: Mr. Robot -> Ozark
# Support: 0.005470120755495923
# Confidence: 0.6162790697674418
# Lift: 3.18120826157525
# ...
